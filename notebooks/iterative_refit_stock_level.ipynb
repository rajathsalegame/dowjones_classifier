# %%
from data import Portfolio, Dataset
from utils import *
import yfinance as yf
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd

# %%
# define stock list of portfolio (just AAPL in this case)
stock_list = ['AAPL']

# define desired start and end dates
start = '1980-01-01'
end = '2020-01-01'

# construct pandas dataframe of portfolio returns to instantiate Portfolio object 
# (in this case from yfinance)
returns = yf.Ticker('AAPL').history(start=start,end=end)

# construct Portfolio object implemented in data.py
apple = Portfolio('AAPL', stock_list, returns, start=start,end=end)

# %%
ax1 = apple.price_plot(['returns'],'Close',start,end)
plt.show()

# %%
# define feature names, target name, periods
feature_names = stock_list
target_name = 'returns'
periods = list(range(1,21)) + list(range(40,260,20))

# instantiate data object 
apple_data = Dataset(apple, 'Close', feature_names, periods, target_name)

# %%
print("Number of features", apple_data.n_features)
print("Number of classes", apple_data.n_classes)
print("Number of datapoints", apple_data.n_samples)
# Out:
# Number of features 31
# Number of classes 2
# Number of datapoints 9605

# %%
print('Number of negative movement days in AAPL', apple_data.target[apple_data.target == 0].shape[0])
print('Number of positive movement days in AAPL', apple_data.target[apple_data.target == 1].shape[0])
# Out:
# Number of negative movement days in AAPL 4078
# Number of positive movement days in AAPL 5527

# %% [markdown]
# We first display summary statistics:

# %%
df_stat = apple_data.statistics(features=['AAPL'],periods=periods)
display(df_stat)
# Out:
#             (AAPL, 1)    (AAPL, 2)    (AAPL, 3)    (AAPL, 4)    (AAPL, 5)  \
# count     9605.000000  9605.000000  9605.000000  9605.000000  9605.000000
# mean         0.001160     0.002323     0.003463     0.004570     0.005698
# std          0.029000     0.041068     0.049893     0.056890     0.063447
# var          0.000841     0.001687     0.002489     0.003236     0.004026
# kurtosis    18.084764    11.311113     9.340400     7.571508     6.906095
# skewness    -0.382236    -0.085574    -0.030444    -0.016608     0.010410
# min         -0.519637    -0.546828    -0.583082    -0.558912    -0.589124
# 25%         -0.013423    -0.018868    -0.022989    -0.026316    -0.028702
# 50%          0.000000     0.000000     0.000000     0.000841     0.003509
# 75%          0.015340     0.022449     0.028402     0.034063     0.038462
# max          0.327869     0.475410     0.475410     0.525424     0.666667
#
#             (AAPL, 6)    (AAPL, 7)    (AAPL, 8)    (AAPL, 9)   (AAPL, 10)  \
# count     9605.000000  9605.000000  9605.000000  9605.000000  9605.000000
# mean         0.006830     0.007976     0.009123     0.010270     0.011405
# std          0.069354     0.074949     0.080117     0.084993     0.089599
# var          0.004810     0.005617     0.006419     0.007224     0.008028
# kurtosis     6.173979     5.826516     5.460062     5.135380     4.664205
# skewness    -0.017472    -0.013748    -0.002635    -0.000389     0.005409
# min         -0.586103    -0.595166    -0.610272    -0.634441    -0.628032
# 25%         -0.031579    -0.034483    -0.036388    -0.038225    -0.039370
# 50%          0.004743     0.006098     0.007145     0.008155     0.009259
# 75%          0.043478     0.048387     0.053571     0.056738     0.059378
# max          0.666667     0.764706     0.764706     0.800000     0.836735
#
#           ...   (AAPL, 60)   (AAPL, 80)  (AAPL, 100)  (AAPL, 120)  \
# count     ...  9605.000000  9605.000000  9605.000000  9605.000000
# mean      ...     0.072773     0.097935     0.123541     0.148984
# std       ...     0.241542     0.290196     0.339109     0.384302
# var       ...     0.058343     0.084214     0.114995     0.147688
# kurtosis  ...     1.249495     1.641189     1.760391     2.181756
# skewness  ...     0.294471     0.573997     0.804786     0.968987
# min       ...    -0.763926    -0.765306    -0.753463    -0.747253
# 25%       ...    -0.073684    -0.081633    -0.100000    -0.100000
# 50%       ...     0.066401     0.086957     0.101484     0.127458
# 75%       ...     0.212194     0.257249     0.288288     0.320000
# max       ...     1.352941     1.705882     1.875000     2.411765
#
#           (AAPL, 140)  (AAPL, 160)  (AAPL, 180)  (AAPL, 200)  (AAPL, 220)  \
# count     9605.000000  9605.000000  9605.000000  9605.000000  9605.000000
# mean         0.175169     0.201045     0.227600     0.254097     0.281397
# std          0.430157     0.474186     0.517139     0.557614     0.596333
# var          0.185035     0.224853     0.267433     0.310934     0.355614
# kurtosis     2.926230     3.254798     3.190305     3.638053     3.595004
# skewness     1.138349     1.284594     1.363823     1.439311     1.429844
# min         -0.723112    -0.773438    -0.800448    -0.780303    -0.753541
# 25%         -0.106195    -0.107692    -0.104132    -0.116883    -0.129310
# 50%          0.138614     0.160270     0.166667     0.182609     0.206897
# 75%          0.357202     0.395263     0.438525     0.483871     0.536232
# max          3.000000     3.250000     3.294118     3.764706     4.062500
#
#           (AAPL, 240)
# count     9605.000000
# mean         0.308902
# std          0.631024
# var          0.398192
# kurtosis     2.880139
# skewness     1.328833
# min         -0.737892
# 25%         -0.153190
# 50%          0.222222
# 75%          0.587211
# max          4.062500
#
# [11 rows x 31 columns]

# %% [markdown]
# We first GridSearch on the data until 1996 using 5-fold cross validation:

# %%
from sklearn.model_selection import GridSearchCV

def algorithm_pipeline(X_train_data, y_train_data, model, param_grid, cv=10, scoring_fit='roc_auc'):
    
    gs = GridSearchCV(estimator=model,param_grid=param_grid, cv=cv, n_jobs=-1, scoring=scoring_fit,verbose=2)
    
    fitted_model = gs.fit(X_train_data, y_train_data)
    
    return fitted_model

# %%
from sklearn.model_selection import train_test_split

X_1996 = apple_data.data.loc['1980-01-01':'1996-01-01'].to_numpy()
y_1996 = apple_data.target.loc['1980-01-01':'1996-01-01'].to_numpy()

# %%
import xgboost as xgb

params = {'learning_rate': [0.01, 0.05, 0.1], 'max_depth': [6, 10, 20, 50],'min_child_weight': [1, 2, 5, 11, 20],'colsample_bytree': [0.3, 0.4, 0.6, 0.7, 0.8]}

xgb_model = xgb.XGBClassifier(n_estimators=200, objective='binary:logistic')

model = algorithm_pipeline(X_1996, y_1996, xgb_model, params, cv=5)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:   35.0s
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 981 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 1426 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:  2.8min finished

# %%
print('Best ROC AUC', model.best_score_)
print('Best params', model.best_params_)
# Out:
# Best ROC AUC 1.0
# Best params {'colsample_bytree': 0.3, 'learning_rate': 0.05, 'max_depth': 6, 'min_child_weight': 1}

# %% [markdown]
# We have now gridsearched and have our optimal parameters. Seems like a massive overfitting problem. We now train the data iteratively year by year until 2014, adding in the data from the year, and computing the feature importances at each step.

# %%
from sklearn import metrics

params = model.best_params_

xgb_model = xgb.XGBClassifier(**params)

years = list(range(1997,2014))

# initialize data
X = apple_data.data.loc['1990-01-01':'1996-01-01'].to_numpy()
y = apple_data.target.loc['1990-01-01':'1996-01-01'].to_numpy()

# fit on data until 1996
xgb_model.fit(X, y)
# save model
xgb_model.save_model(f'model_1996_stock.model')
impt = xgb_model.get_booster().get_score(importance_type='weight')
for key in impt.keys():
    impt[key] = [impt[key]]

roc_auc_scores = []

for year in years:
    print(f'iterative training on year {year}...')
    year_X, year_y = apple_data.data.loc[f'{year}-01-01':f'{year}-12-31'].to_numpy(), apple_data.target.loc[f'{year}-01-01':f'{year}-12-31'].to_numpy()
    
    X_train, y_train = np.concatenate((X, year_X), axis=0), np.concatenate((y, year_y), axis=0)
    
    X_test, y_test = apple_data.data.loc[f'{year+1}-01-01':f'{year+1}-12-31'].to_numpy(), apple_data.target.loc[f'{year+1}-01-01':f'{year+1}-12-31'].to_numpy()
    
    if os.path.isfile(f'model_{year-1}_stock.model'):
        xgb_model.fit(X_train, y_train, xgb_model=f'model_{year-1}_stock.model')
    else:
        xgb_model.fit(X_train, y_train)
        
    xgb_model.save_model(f'model_{year}_stock.model')
    # feature importances
    impt_year = xgb_model.get_booster().get_score(importance_type='gain')

    for key in impt_year.keys():
        impt[key].append(impt_year[key])
    
    # check predictions and get ROC_AUC
    preds = xgb_model.predict(X_test)
    roc_auc_scores.append(metrics.roc_auc_score(y_test, preds))
# Out:
# iterative training on year 1997...
# iterative training on year 1998...
# iterative training on year 1999...
# iterative training on year 2000...
# iterative training on year 2001...
# iterative training on year 2002...
# iterative training on year 2003...
# iterative training on year 2004...
# iterative training on year 2005...
# iterative training on year 2006...
# iterative training on year 2007...
# iterative training on year 2008...
# iterative training on year 2009...
# iterative training on year 2010...
# iterative training on year 2011...
# iterative training on year 2012...
# iterative training on year 2013...

# %% [markdown]
# We can now look at feature importances:

# %%
impt_df = pd.DataFrame(impt, index=[1996] + years)
impt_df = impt_df.reindex(sorted(impt_df.columns, key= lambda x: int(x[1:])), axis=1)
display(impt_df)
# Out:
#               f0          f1         f2          f3          f4         f5  \
# 1996   29.000000  168.000000  96.000000  200.000000  102.000000  98.000000
# 1997  280.977221    4.271854   3.842512    2.126035    1.031838   1.132495
# 1998  192.057373    3.759165   3.336624    1.983788    0.850883   0.984552
# 1999  144.896134    3.572883   3.270034    1.925195    0.812246   0.941335
# 2000  129.515667    3.471462   3.124515    1.824442    0.780124   0.903663
# 2001  129.515667    3.471462   3.124515    1.824442    0.780124   0.903663
# 2002  129.515667    3.471462   3.124515    1.824442    0.780124   0.903663
# 2003  129.515667    3.471462   3.124515    1.824442    0.780124   0.903663
# 2004  129.515667    3.471462   3.124515    1.824442    0.780124   0.903663
# 2005  109.140532    3.378139   3.009205    1.801106    0.774415   0.899770
# 2006   92.791667    3.252431   3.009205    1.780381    0.758839   0.899770
# 2007   81.338546    3.144399   3.009205    1.769831    0.758839   0.899770
# 2008   81.338546    3.136339   3.009205    1.769831    0.753124   0.895996
# 2009   77.463113    3.128887   3.009205    1.769831    0.753124   0.895996
# 2010   77.463113    3.128887   3.009205    1.769831    0.753124   0.895996
# 2011   75.580450    3.128887   2.978393    1.767367    0.754022   0.898550
# 2012   72.159851    3.128887   2.817729    1.736345    0.754022   0.898550
# 2013   70.789402    3.114525   2.817729    1.709135    0.754022   0.898550
#
#               f6          f7         f8          f9  ...        f21  \
# 1996  105.000000  110.000000  78.000000  104.000000  ...  50.000000
# 1997    1.095268    0.636818   0.909686    0.781871  ...   0.486795
# 1998    1.022789    0.587765   0.778876    0.665849  ...   0.448600
# 1999    0.952980    0.577453   0.764049    0.662357  ...   0.438497
# 2000    0.952980    0.576049   0.757162    0.662357  ...   0.438497
# 2001    0.952980    0.576049   0.757162    0.662357  ...   0.438497
# 2002    0.952980    0.576049   0.757162    0.662357  ...   0.438497
# 2003    0.952980    0.576049   0.757162    0.662357  ...   0.438497
# 2004    0.952980    0.576049   0.757162    0.662357  ...   0.438497
# 2005    0.938119    0.575108   0.794422    0.682207  ...   0.438497
# 2006    0.922957    0.567894   0.782883    0.674206  ...   0.416559
# 2007    0.922957    0.560259   0.782883    0.674206  ...   0.416559
# 2008    0.922957    0.560259   0.770748    0.669338  ...   0.392704
# 2009    0.896502    0.546334   0.766823    0.662211  ...   0.392704
# 2010    0.896502    0.546334   0.766823    0.662211  ...   0.392704
# 2011    0.905888    0.553214   0.766823    0.662211  ...   0.452420
# 2012    0.887143    0.549723   0.757102    0.662211  ...   0.452420
# 2013    0.877956    0.554266   0.757102    0.662211  ...   0.452839
#
#             f22        f23        f24        f25        f26        f27  \
# 1996  77.000000  72.000000  82.000000  55.000000  67.000000  66.000000
# 1997   0.538400   0.755561   0.623687   0.809995   0.753856   0.636936
# 1998   0.451106   0.687761   0.535736   0.679794   0.702705   0.588327
# 1999   0.448218   0.682321   0.526220   0.658738   0.665429   0.512256
# 2000   0.445010   0.678519   0.522248   0.658738   0.653631   0.512256
# 2001   0.445010   0.678519   0.522248   0.658738   0.653631   0.512256
# 2002   0.445010   0.678519   0.522248   0.658738   0.653631   0.512256
# 2003   0.445010   0.678519   0.522248   0.658738   0.653631   0.512256
# 2004   0.445010   0.678519   0.522248   0.658738   0.653631   0.512256
# 2005   0.445010   0.678519   0.517505   0.651835   0.685932   0.519529
# 2006   0.445010   0.678519   0.533727   0.651835   0.685932   0.519529
# 2007   0.445010   0.678519   0.531667   0.627054   0.642477   0.498439
# 2008   0.432623   0.675002   0.531667   0.627054   0.639867   0.492128
# 2009   0.432623   0.667221   0.527955   0.627054   0.621427   0.492128
# 2010   0.432623   0.667221   0.527955   0.627054   0.621427   0.492128
# 2011   0.432086   0.667221   0.612471   0.633450   0.641261   0.492128
# 2012   0.432086   0.667221   0.617220   0.637466   0.644669   0.496692
# 2013   0.432086   0.655763   0.611411   0.634825   0.666152   0.496722
#
#             f28        f29        f30
# 1996  76.000000  66.000000  68.000000
# 1997   0.659828   0.602897   0.610709
# 1998   0.618871   0.548399   0.576325
# 1999   0.601977   0.544480   0.556403
# 2000   0.596690   0.538202   0.551533
# 2001   0.596690   0.534435   0.551533
# 2002   0.596690   0.534435   0.551533
# 2003   0.596690   0.534435   0.551533
# 2004   0.596690   0.534435   0.551533
# 2005   0.664866   0.632460   0.718943
# 2006   0.664866   0.632460   0.706514
# 2007   0.653766   0.632460   0.706514
# 2008   0.653766   0.632460   0.706514
# 2009   0.650158   0.632460   0.706514
# 2010   0.650158   0.632460   0.706514
# 2011   0.647506   0.637673   0.741758
# 2012   0.658557   0.636383   0.736268
# 2013   0.729077   0.746681   0.753810
#
# [18 rows x 31 columns]

# %%
plt.plot(years, roc_auc_scores)
plt.xlabel('Year')
plt.ylabel('ROC AUC')
plt.title('ROC AUC vs Year')
plt.show()

# %% [markdown]
# We now evaluate on data from 2014 onwards as our validation set:

# %%
# initialize data
X_test = apple_data.data.loc['2014-01-01':'2020-01-01'].to_numpy()
y_test = apple_data.target.loc['2014-01-01':'2020-01-01'].to_numpy()

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,8))

# predict probabilities
lr_probs = xgb_model.predict_proba(X_test)
# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]

# generate a no skill prediction (majority class)
ns_probs = [0 for _ in range(len(y_test))]

# calculate scores
ns_auc = metrics.roc_auc_score(y_test, ns_probs)
lr_auc = metrics.roc_auc_score(y_test, lr_probs)
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('XGBoost: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
ns_fpr, ns_tpr, _ = metrics.roc_curve(y_test, ns_probs)
lr_fpr, lr_tpr, _ = metrics.roc_curve(y_test, lr_probs)
# plot the roc curve for the model
ax1.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
ax1.plot(lr_fpr, lr_tpr, marker='.', label='XGBoost')
# axis labels
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('Receiver Operating Characteristic Curve')
# show the legend
ax1.legend()

# predict class values
yhat = xgb_model.predict(X_test)
lr_precision, lr_recall, _ = metrics.precision_recall_curve(y_test, lr_probs)
lr_auc = metrics.auc(lr_recall, lr_precision)
# summarize scores
print('No Skill: PR AUC=%.3f' % (len(y_test[y_test==1]) / len(y_test)))
print('XGBoost: PR AUC=%.3f' % (lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
ax2.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
ax2.plot(lr_recall, lr_precision, marker='.', label='XGBoost')
# axis labels
ax2.set_xlabel('Recall')
ax2.set_ylabel('Precision')
ax2.set_title('Precision Recall Curve')
# show the legend
ax2.legend()

plt.show()
# Out:
# No Skill: ROC AUC=0.500
# XGBoost: ROC AUC=0.999
# No Skill: PR AUC=0.536
# XGBoost: PR AUC=0.999

# %% [markdown]
# These results seem pretty reasonable since there's a ridiculous amount of autocorrelation between
